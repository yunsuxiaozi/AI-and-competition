# %% [markdown]
# ## Created by <a href="https://github.com/yunsuxiaozi">yunsuxiaozi</a> 2024/6/8
#
# #### 这个notebook是模型的训练和推理。

# %%
#necessary
import polars as pl#和pandas类似,但是处理大型数据集有更好的性能.
import pandas as pd#导入csv文件的库
import numpy as np#进行矩阵运算的库
import json#用于读取和写入json数据格式
#model lgb分类模型,日志评估,早停防止过拟合
from  lightgbm import LGBMClassifier,log_evaluation
#metric
from sklearn.metrics import roc_auc_score#导入roc_auc曲线
#KFold是直接分成k折,StratifiedKFold还要考虑每种类别的占比
from sklearn.model_selection import StratifiedGroupKFold
import dill#对对象进行序列化和反序列化(例如保存和加载树模型)

# %%
#config
class Config():
    seed=2024#随机种子
    num_folds=10#K折交叉验证
    TARGET_NAME ='label'#标签
import random#提供了一些用于生成随机数的函数
#设置随机种子,保证模型可以复现
def seed_everything(seed):
    np.random.seed(seed)#numpy的随机种子
    random.seed(seed)#python内置的随机种子
seed_everything(Config.seed)

# %% [markdown]
# #### 这里还是对数据做了些特征工程

# %%
train_feats=pl.read_csv("/kaggle/input/2024kdd-data/train_feats.csv")
train_feats=train_feats.to_pandas()
valid_feats=pl.read_csv("/kaggle/input/2024kdd-data/valid_feats.csv")
valid_feats=valid_feats.to_pandas()

#698,754(author_count=2),512,151(author_count>1800) 测试数据中没有这样的数据
train_feats=train_feats[~train_feats['authorid'].isin([512,151,698,754])]

#特征交叉
def deal_df(df):
    df['title_readable']=df['title_ari']+df['title_McAlpine_EFLAW']+df['title_CLRI']
    df['abs_readable']=df['abs_ari']+df['abs_McAlpine_EFLAW']+df['abs_CLRI']
    
    tops=['title_ari','title_McAlpine_EFLAW','title_CLRI']
    for i in range(len(tops)):
        for j in range(i+1,len(tops)):
            df[f"{tops[i]}+{tops[j]}"]=df[tops[i]]+df[tops[j]]
            df[f"{tops[i]}-{tops[j]}"]=df[tops[i]]-df[tops[j]]
            df[f"{tops[i]}*{tops[j]}"]=df[tops[i]]*df[tops[j]]
            df[f"{tops[i]}/{tops[j]}"]=df[tops[i]]/df[tops[j]]
            
    tops=['abs_ari','abs_McAlpine_EFLAW','abs_CLRI']
    for i in range(len(tops)):
        for j in range(i+1,len(tops)):
            df[f"{tops[i]}+{tops[j]}"]=df[tops[i]]+df[tops[j]]
            df[f"{tops[i]}-{tops[j]}"]=df[tops[i]]-df[tops[j]]
            df[f"{tops[i]}*{tops[j]}"]=df[tops[i]]*df[tops[j]]
            df[f"{tops[i]}/{tops[j]}"]=df[tops[i]]/df[tops[j]]
    tops=['title_wordcount','abs_wordcount']
    for i in range(len(tops)):
        for j in range(i+1,len(tops)):
            df[f"{tops[i]}+{tops[j]}"]=df[tops[i]]+df[tops[j]]
            df[f"{tops[i]}-{tops[j]}"]=df[tops[i]]-df[tops[j]]
            df[f"{tops[i]}*{tops[j]}"]=df[tops[i]]*df[tops[j]]
            df[f"{tops[i]}/{tops[j]}"]=df[tops[i]]/df[tops[j]]
            
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    
    return df
train_feats=deal_df(train_feats)
valid_feats=deal_df(valid_feats)

train_feats.head()
# Out:
#    authorid  title_len  title_wordcount  title_ari  title_McAlpine_EFLAW  \
# 0       0.0   4.795791         2.944439  18.970000              3.610918
# 1       0.0   4.820282         2.772589  21.148235              3.555348
# 2       0.0   4.615120         2.639057  15.712857              3.091042
# 3       0.0   4.644391         2.708050  20.222143              3.367296
# 4       0.0   4.897840         2.708050  24.082000              3.157000
#
#    title_CLRI  title_word_maxlen  title_word_meanlen  title_word_stdlen  \
# 0   21.755556           2.708050            1.905419           1.506033
# 1   25.002354           2.564949            2.112231           1.519022
# 2   21.971428           2.708050            2.050171           1.525656
# 3   25.345715           2.484907            2.005334           1.396379
# 4   32.389330           3.044522            2.258782           1.721640
#
#    title_word_sumlen  ...  abs_ari*abs_CLRI  abs_ari/abs_CLRI  \
# 0           4.644391  ...        950.222000          0.461013
# 1           4.700481  ...        950.222000          0.461013
# 2           4.488637  ...        214.409559          0.836030
# 3           4.510859  ...        950.222000          0.461013
# 4           4.795791  ...        330.976640          0.835311
#
#    abs_McAlpine_EFLAW+abs_CLRI  abs_McAlpine_EFLAW-abs_CLRI  \
# 0                   -44.301388                    46.498612
# 1                   -44.301388                    46.498612
# 2                    21.254241                   -10.774599
# 3                   -44.301388                    46.498612
# 4                    25.511142                   -14.299998
#
#    abs_McAlpine_EFLAW*abs_CLRI  abs_McAlpine_EFLAW/abs_CLRI  \
# 0                   -49.876998                    -0.024199
# 1                   -49.876998                    -0.024199
# 2                    83.912694                     0.327194
# 3                   -49.876998                    -0.024199
# 4                   111.582106                     0.281608
#
#    title_wordcount+abs_wordcount  title_wordcount-abs_wordcount  \
# 0                       2.944439                       2.944439
# 1                       2.772589                       2.772589
# 2                       7.714231                      -2.436117
# 3                       2.708050                       2.708050
# 4                       8.146130                      -2.730029
#
#    title_wordcount*abs_wordcount  title_wordcount/abs_wordcount
# 0                       0.000000                            NaN
# 1                       0.000000                            NaN
# 2                      13.393676                       0.519993
# 3                       0.000000                            NaN
# 4                      14.726593                       0.497979
#
# [5 rows x 1280 columns]

# %% [markdown]
# #### 相关性特征的构建

# %%
#计算两组变量的皮尔逊相关系数
def pearson_corr(x1,x2,eps=1e-15):
    mean_x1=np.mean(x1)
    mean_x2=np.mean(x2)
    std_x1=np.std(x1)
    std_x2=np.std(x2)
    pearson=np.mean((x1-mean_x1)*(x2-mean_x2))/(std_x1*std_x2+eps)
    return pearson

def corr_feats(margin=0.1):
    train_feats[f'corr_{margin}']=0
    valid_feats[f'corr_{margin}']=0
    drop_cols=[]
    for col in valid_feats.columns:
        if 'corr' in col:
            drop_cols+=[col]
    for col in valid_feats.drop(['authorid']+drop_cols,axis=1).columns:
        tmp_df=train_feats[[col,'label']].dropna().copy()
        pearson=pearson_corr(tmp_df[col].values,tmp_df['label'].values)
        max_value,min_value=float(tmp_df[col].max()),float(tmp_df[col].min())
        if abs(pearson)>margin:
            train_feats[f'corr_{margin}']+=pearson*(train_feats[col]-min_value)/(max_value-min_value)
            valid_feats[f'corr_{margin}']+=pearson*(valid_feats[col]-min_value)/(max_value-min_value)
    tmp_df=train_feats[[f'corr_{margin}','label']].dropna().copy()
    print(f"margin:{margin},len(tmp_df):{len(tmp_df)},{pearson_corr(tmp_df[f'corr_{margin}'].values,tmp_df['label'].values)}")
for margin in [0.1,0.05,0.025,0.01,0.005]:
    corr_feats(margin)
train_feats.head()
# Out:
# margin:0.1,len(tmp_df):143896,0.2389044131464588
# margin:0.05,len(tmp_df):72345,0.24274503270248282
# margin:0.025,len(tmp_df):57259,0.2494189186709124
# margin:0.01,len(tmp_df):57158,0.24808946098186307
# margin:0.005,len(tmp_df):57150,0.2485095029879458
#    authorid  title_len  title_wordcount  title_ari  title_McAlpine_EFLAW  \
# 0       0.0   4.795791         2.944439  18.970000              3.610918
# 1       0.0   4.820282         2.772589  21.148235              3.555348
# 2       0.0   4.615120         2.639057  15.712857              3.091042
# 3       0.0   4.644391         2.708050  20.222143              3.367296
# 4       0.0   4.897840         2.708050  24.082000              3.157000
#
#    title_CLRI  title_word_maxlen  title_word_meanlen  title_word_stdlen  \
# 0   21.755556           2.708050            1.905419           1.506033
# 1   25.002354           2.564949            2.112231           1.519022
# 2   21.971428           2.708050            2.050171           1.525656
# 3   25.345715           2.484907            2.005334           1.396379
# 4   32.389330           3.044522            2.258782           1.721640
#
#    title_word_sumlen  ...  abs_McAlpine_EFLAW/abs_CLRI  \
# 0           4.644391  ...                    -0.024199
# 1           4.700481  ...                    -0.024199
# 2           4.488637  ...                     0.327194
# 3           4.510859  ...                    -0.024199
# 4           4.795791  ...                     0.281608
#
#    title_wordcount+abs_wordcount  title_wordcount-abs_wordcount  \
# 0                       2.944439                       2.944439
# 1                       2.772589                       2.772589
# 2                       7.714231                      -2.436117
# 3                       2.708050                       2.708050
# 4                       8.146130                      -2.730029
#
#    title_wordcount*abs_wordcount  title_wordcount/abs_wordcount  corr_0.1  \
# 0                       0.000000                            NaN  4.998334
# 1                       0.000000                            NaN  4.998334
# 2                      13.393676                       0.519993  4.998334
# 3                       0.000000                            NaN  4.998334
# 4                      14.726593                       0.497979  4.998334
#
#    corr_0.05  corr_0.025  corr_0.01  corr_0.005
# 0        NaN         NaN        NaN         NaN
# 1        NaN         NaN        NaN         NaN
# 2  11.488661   12.982249  12.887514   12.597896
# 3        NaN         NaN        NaN         NaN
# 4  11.493188   13.052029  13.000854   12.714798
#
# [5 rows x 1285 columns]

# %% [markdown]
# #### 模型的训练代码

# %%
#这里尝试自定义评估指标  https://www.kaggle.com/competitions/home-credit-credit-risk-model-stability/discussion/500868
def weight_rocauc(authorid,y_true,y_pro):
    max_authorid=np.max(authorid).astype(int)+1
    total_weight_auc=0
    cnt=0
    for id in range(max_authorid):
        cur_idx=np.where(authorid==id)[0]
        if len(cur_idx)>0:#authorid可能是
            auc=roc_auc_score(y_true[cur_idx],y_pro[cur_idx])
            cnt+=int(auc<0.5)
            weight_auc=np.sum(y_true[cur_idx]==0)*auc
            total_weight_auc+=weight_auc
    print(f"cnt:{cnt}")
    total_weight_auc/=np.sum(y_true==0)
    return total_weight_auc#'weight_rocauc',total_weight_auc,True#名称,值,是否越高越好
#保存训练好的树模型,obj是保存的模型,path是需要保存的路径
def pickle_dump(obj, path):
    #打开指定的路径path,binary write(二进制写入)
    with open(path, mode="wb") as f:
        #将obj对象保存到f,使用协议版本4进行序列化
        dill.dump(obj, f, protocol=4)

choose_cols=[ col for col in valid_feats.drop(['authorid'],axis=1).columns]#.drop(['index'],axis=1)

def fit_and_predict(train_feats=train_feats,test_feats=valid_feats,model=None,fold=10,seed=2024,name='lgb'):
    X=train_feats[choose_cols].copy()
    y=train_feats[Config.TARGET_NAME].copy()
    authorid=train_feats['authorid'].values
    test_X=test_feats[choose_cols].copy()
    oof_pred_pro=np.zeros((len(X)))
    test_pred_pro=np.zeros((fold,len(test_X),2))

    #10折交叉验证
    gkf = StratifiedGroupKFold(n_splits=fold,shuffle=True)
    for fold, (train_index, valid_index) in (enumerate(gkf.split(X,y,train_feats['authorid'].values))):
        print(f"name {name},fold:{fold}")

        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
        
        valid_authorid=authorid[valid_index]
        
        model.fit(X_train,y_train,eval_set=[(X_valid, y_valid)],
                      callbacks=[log_evaluation(100)],
                     # eval_metric=lambda y_true, y_pred: weight_rocauc(valid_authorid,y_true,y_pred)
                     )
        valid_pred=model.predict_proba(X_valid)[:,1]
        

        oof_pred_pro[valid_index]=valid_pred
        #将数据分批次进行预测.
        test_pred_pro[fold]=model.predict_proba(test_X)
        pickle_dump(model, f'/kaggle/working/{name}_fold{fold}.model') #保存训练好的模型   
    print(f"weight_roc_auc:{weight_rocauc(authorid,y.values,oof_pred_pro)}")
    
    #保存oof_pred_pro,仔细研究一下模型对发论文多的作者效果好还是对发论文少的作者效果好
    np.save(f'{name}_oof_pred_pro.npy', oof_pred_pro)
    
    test_preds=test_pred_pro.mean(axis=0)[:,1]
    
    return oof_pred_pro,test_preds

lgb_params1 = {"boosting_type": "gbdt","objective": "binary","metric": "auc",       
                         'random_state': 2024, 'n_estimators': 1024,
                         'reg_alpha': 0.1, 'reg_lambda': 10, 
                         'colsample_bytree': 0.8, 'subsample': 0.8,
                         'learning_rate': 0.05, 'num_leaves': 64, 'min_child_samples': 62,
                         'max_bin':245, "extra_trees": True,
                         'device':'gpu','gpu_use_dp':True,#GPU环境的参数
                    }

#之前使用的一组参数:weight_roc_auc:0.6982612255710695
lgb_params2 = {"boosting_type": "gbdt","objective": "binary","metric": "auc",       
     'random_state': 2024, 'n_estimators': 1536,
     'reg_alpha': 2.6756579164398144, 'reg_lambda': 1.6187614490530422, 
     'colsample_bytree': 0.7, 'subsample': 0.7,
     'learning_rate': 0.030479973315991688, 'num_leaves': 50, 'min_child_samples': 62,
     'max_bin':245,
     'device':'gpu','gpu_use_dp':True,#GPU环境的参数
}

lgb_oof_pred_pro1,test_preds1=fit_and_predict(model=LGBMClassifier(**lgb_params1),fold=Config.num_folds,seed=2024,name='lgb1')

lgb_oof_pred_pro2,test_preds2=fit_and_predict(model=LGBMClassifier(**lgb_params2),fold=Config.num_folds,seed=42,name='lgb2')

test_preds=(test_preds1+test_preds2)/2

print(test_preds[:10])
# Out:
# name lgb1,fold:0
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 113933, number of negative: 15568
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293077
# [LightGBM] [Info] Number of data points in the train set: 129501, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (156.11 MB) transferred to GPU in 0.093319 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.879785 -> initscore=1.990393
# [LightGBM] [Info] Start training from score 1.990393
# [100]	valid_0's auc: 0.751934
# [200]	valid_0's auc: 0.763989
# [300]	valid_0's auc: 0.767503
# [400]	valid_0's auc: 0.772023
# [500]	valid_0's auc: 0.775528
# [600]	valid_0's auc: 0.776258
# [700]	valid_0's auc: 0.778621
# [800]	valid_0's auc: 0.778396
# [900]	valid_0's auc: 0.780198
# [1000]	valid_0's auc: 0.781493
# name lgb1,fold:1
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 115490, number of negative: 15280
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293319
# [LightGBM] [Info] Number of data points in the train set: 130770, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (157.14 MB) transferred to GPU in 0.096954 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.883154 -> initscore=2.022639
# [LightGBM] [Info] Start training from score 2.022639
# [100]	valid_0's auc: 0.838218
# [200]	valid_0's auc: 0.843761
# [300]	valid_0's auc: 0.844418
# [400]	valid_0's auc: 0.843725
# [500]	valid_0's auc: 0.843492
# [600]	valid_0's auc: 0.843464
# [700]	valid_0's auc: 0.844349
# [800]	valid_0's auc: 0.842755
# [900]	valid_0's auc: 0.841915
# [1000]	valid_0's auc: 0.841108
# name lgb1,fold:2
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 116742, number of negative: 14855
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293389
# [LightGBM] [Info] Number of data points in the train set: 131597, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (158.13 MB) transferred to GPU in 0.095493 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.887117 -> initscore=2.061630
# [LightGBM] [Info] Start training from score 2.061630
# [100]	valid_0's auc: 0.714594
# [200]	valid_0's auc: 0.726234
# [300]	valid_0's auc: 0.731147
# [400]	valid_0's auc: 0.733426
# [500]	valid_0's auc: 0.738479
# [600]	valid_0's auc: 0.740504
# [700]	valid_0's auc: 0.742484
# [800]	valid_0's auc: 0.741775
# [900]	valid_0's auc: 0.7435
# [1000]	valid_0's auc: 0.74351
# name lgb1,fold:3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 112883, number of negative: 15746
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293694
# [LightGBM] [Info] Number of data points in the train set: 128629, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (154.56 MB) transferred to GPU in 0.102660 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.877586 -> initscore=1.969766
# [LightGBM] [Info] Start training from score 1.969766
# [100]	valid_0's auc: 0.828914
# [200]	valid_0's auc: 0.853724
# [300]	valid_0's auc: 0.862122
# [400]	valid_0's auc: 0.862553
# [500]	valid_0's auc: 0.864088
# [600]	valid_0's auc: 0.86518
# [700]	valid_0's auc: 0.866806
# [800]	valid_0's auc: 0.866731
# [900]	valid_0's auc: 0.868608
# [1000]	valid_0's auc: 0.868898
# name lgb1,fold:4
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 116562, number of negative: 15850
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293806
# [LightGBM] [Info] Number of data points in the train set: 132412, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (159.11 MB) transferred to GPU in 0.103871 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.880298 -> initscore=1.995254
# [LightGBM] [Info] Start training from score 1.995254
# [100]	valid_0's auc: 0.848424
# [200]	valid_0's auc: 0.858497
# [300]	valid_0's auc: 0.861133
# [400]	valid_0's auc: 0.863425
# [500]	valid_0's auc: 0.862956
# [600]	valid_0's auc: 0.863132
# [700]	valid_0's auc: 0.86319
# [800]	valid_0's auc: 0.863744
# [900]	valid_0's auc: 0.86349
# [1000]	valid_0's auc: 0.863245
# name lgb1,fold:5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 114300, number of negative: 15375
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293256
# [LightGBM] [Info] Number of data points in the train set: 129675, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (155.82 MB) transferred to GPU in 0.100092 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.881434 -> initscore=2.006084
# [LightGBM] [Info] Start training from score 2.006084
# [100]	valid_0's auc: 0.788838
# [200]	valid_0's auc: 0.802936
# [300]	valid_0's auc: 0.808151
# [400]	valid_0's auc: 0.809919
# [500]	valid_0's auc: 0.810388
# [600]	valid_0's auc: 0.809736
# [700]	valid_0's auc: 0.81087
# [800]	valid_0's auc: 0.808767
# [900]	valid_0's auc: 0.809724
# [1000]	valid_0's auc: 0.809503
# name lgb1,fold:6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 112852, number of negative: 14992
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293054
# [LightGBM] [Info] Number of data points in the train set: 127844, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (153.62 MB) transferred to GPU in 0.095565 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.882732 -> initscore=2.018561
# [LightGBM] [Info] Start training from score 2.018561
# [100]	valid_0's auc: 0.707051
# [200]	valid_0's auc: 0.726524
# [300]	valid_0's auc: 0.735139
# [400]	valid_0's auc: 0.740049
# [500]	valid_0's auc: 0.74185
# [600]	valid_0's auc: 0.742261
# [700]	valid_0's auc: 0.743988
# [800]	valid_0's auc: 0.744178
# [900]	valid_0's auc: 0.745715
# [1000]	valid_0's auc: 0.744681
# name lgb1,fold:7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 113258, number of negative: 15628
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293353
# [LightGBM] [Info] Number of data points in the train set: 128886, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (155.36 MB) transferred to GPU in 0.101889 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.878746 -> initscore=1.980604
# [LightGBM] [Info] Start training from score 1.980604
# [100]	valid_0's auc: 0.784891
# [200]	valid_0's auc: 0.799307
# [300]	valid_0's auc: 0.804295
# [400]	valid_0's auc: 0.807899
# [500]	valid_0's auc: 0.808798
# [600]	valid_0's auc: 0.808727
# [700]	valid_0's auc: 0.80942
# [800]	valid_0's auc: 0.809063
# [900]	valid_0's auc: 0.810557
# [1000]	valid_0's auc: 0.810571
# name lgb1,fold:8
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 115114, number of negative: 14665
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293618
# [LightGBM] [Info] Number of data points in the train set: 129779, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (156.44 MB) transferred to GPU in 0.106324 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.887000 -> initscore=2.060459
# [LightGBM] [Info] Start training from score 2.060459
# [100]	valid_0's auc: 0.743612
# [200]	valid_0's auc: 0.75953
# [300]	valid_0's auc: 0.767257
# [400]	valid_0's auc: 0.768786
# [500]	valid_0's auc: 0.770202
# [600]	valid_0's auc: 0.77348
# [700]	valid_0's auc: 0.774042
# [800]	valid_0's auc: 0.772519
# [900]	valid_0's auc: 0.774163
# [1000]	valid_0's auc: 0.779338
# name lgb1,fold:9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 110930, number of negative: 15167
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293192
# [LightGBM] [Info] Number of data points in the train set: 126097, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (152.00 MB) transferred to GPU in 0.092074 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.879720 -> initscore=1.989777
# [LightGBM] [Info] Start training from score 1.989777
# [100]	valid_0's auc: 0.814959
# [200]	valid_0's auc: 0.825588
# [300]	valid_0's auc: 0.831933
# [400]	valid_0's auc: 0.835957
# [500]	valid_0's auc: 0.839336
# [600]	valid_0's auc: 0.840162
# [700]	valid_0's auc: 0.839767
# [800]	valid_0's auc: 0.839894
# [900]	valid_0's auc: 0.839473
# [1000]	valid_0's auc: 0.839376
# cnt:115
# weight_roc_auc:0.7157773679867705
# name lgb2,fold:0
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 116259, number of negative: 15470
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293362
# [LightGBM] [Info] Number of data points in the train set: 131729, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (158.29 MB) transferred to GPU in 0.103644 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.882562 -> initscore=2.016918
# [LightGBM] [Info] Start training from score 2.016918
# [100]	valid_0's auc: 0.755156
# [200]	valid_0's auc: 0.765328
# [300]	valid_0's auc: 0.777476
# [400]	valid_0's auc: 0.782848
# [500]	valid_0's auc: 0.786129
# [600]	valid_0's auc: 0.787837
# [700]	valid_0's auc: 0.789257
# [800]	valid_0's auc: 0.788912
# [900]	valid_0's auc: 0.788052
# [1000]	valid_0's auc: 0.789003
# [1100]	valid_0's auc: 0.790609
# [1200]	valid_0's auc: 0.791966
# [1300]	valid_0's auc: 0.791946
# [1400]	valid_0's auc: 0.792043
# [1500]	valid_0's auc: 0.793215
# name lgb2,fold:1
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 110125, number of negative: 15482
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293302
# [LightGBM] [Info] Number of data points in the train set: 125607, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (150.93 MB) transferred to GPU in 0.104661 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.876743 -> initscore=1.961938
# [LightGBM] [Info] Start training from score 1.961938
# [100]	valid_0's auc: 0.745693
# [200]	valid_0's auc: 0.774702
# [300]	valid_0's auc: 0.786795
# [400]	valid_0's auc: 0.79143
# [500]	valid_0's auc: 0.794961
# [600]	valid_0's auc: 0.796355
# [700]	valid_0's auc: 0.796496
# [800]	valid_0's auc: 0.798082
# [900]	valid_0's auc: 0.797643
# [1000]	valid_0's auc: 0.798349
# [1100]	valid_0's auc: 0.79935
# [1200]	valid_0's auc: 0.798923
# [1300]	valid_0's auc: 0.799557
# [1400]	valid_0's auc: 0.80072
# [1500]	valid_0's auc: 0.799357
# name lgb2,fold:2
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 111391, number of negative: 14960
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293226
# [LightGBM] [Info] Number of data points in the train set: 126351, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (151.83 MB) transferred to GPU in 0.094509 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.881600 -> initscore=2.007667
# [LightGBM] [Info] Start training from score 2.007667
# [100]	valid_0's auc: 0.733913
# [200]	valid_0's auc: 0.751461
# [300]	valid_0's auc: 0.757669
# [400]	valid_0's auc: 0.760712
# [500]	valid_0's auc: 0.761635
# [600]	valid_0's auc: 0.761384
# [700]	valid_0's auc: 0.762742
# [800]	valid_0's auc: 0.763627
# [900]	valid_0's auc: 0.765009
# [1000]	valid_0's auc: 0.764951
# [1100]	valid_0's auc: 0.764247
# [1200]	valid_0's auc: 0.765963
# [1300]	valid_0's auc: 0.766375
# [1400]	valid_0's auc: 0.767595
# [1500]	valid_0's auc: 0.768096
# name lgb2,fold:3
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 115286, number of negative: 15494
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293293
# [LightGBM] [Info] Number of data points in the train set: 130780, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (157.15 MB) transferred to GPU in 0.101454 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.881526 -> initscore=2.006963
# [LightGBM] [Info] Start training from score 2.006963
# [100]	valid_0's auc: 0.799721
# [200]	valid_0's auc: 0.820759
# [300]	valid_0's auc: 0.831649
# [400]	valid_0's auc: 0.835169
# [500]	valid_0's auc: 0.839937
# [600]	valid_0's auc: 0.842433
# [700]	valid_0's auc: 0.844544
# [800]	valid_0's auc: 0.845199
# [900]	valid_0's auc: 0.845218
# [1000]	valid_0's auc: 0.846065
# [1100]	valid_0's auc: 0.846772
# [1200]	valid_0's auc: 0.847332
# [1300]	valid_0's auc: 0.847387
# [1400]	valid_0's auc: 0.847914
# [1500]	valid_0's auc: 0.848979
# name lgb2,fold:4
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 114792, number of negative: 15611
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293343
# [LightGBM] [Info] Number of data points in the train set: 130403, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1259 dense feature groups (156.70 MB) transferred to GPU in 0.096713 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.880286 -> initscore=1.995146
# [LightGBM] [Info] Start training from score 1.995146
# [100]	valid_0's auc: 0.761294
# [200]	valid_0's auc: 0.80083
# [300]	valid_0's auc: 0.810861
# [400]	valid_0's auc: 0.81535
# [500]	valid_0's auc: 0.816565
# [600]	valid_0's auc: 0.817941
# [700]	valid_0's auc: 0.819682
# [800]	valid_0's auc: 0.821329
# [900]	valid_0's auc: 0.822847
# [1000]	valid_0's auc: 0.824089
# [1100]	valid_0's auc: 0.823781
# [1200]	valid_0's auc: 0.824232
# [1300]	valid_0's auc: 0.824797
# [1400]	valid_0's auc: 0.8264
# [1500]	valid_0's auc: 0.826645
# name lgb2,fold:5
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 115092, number of negative: 15376
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293376
# [LightGBM] [Info] Number of data points in the train set: 130468, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (157.27 MB) transferred to GPU in 0.111205 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.882147 -> initscore=2.012924
# [LightGBM] [Info] Start training from score 2.012924
# [100]	valid_0's auc: 0.735767
# [200]	valid_0's auc: 0.766868
# [300]	valid_0's auc: 0.777716
# [400]	valid_0's auc: 0.787023
# [500]	valid_0's auc: 0.791364
# [600]	valid_0's auc: 0.79392
# [700]	valid_0's auc: 0.795376
# [800]	valid_0's auc: 0.795272
# [900]	valid_0's auc: 0.797617
# [1000]	valid_0's auc: 0.798495
# [1100]	valid_0's auc: 0.798563
# [1200]	valid_0's auc: 0.800114
# [1300]	valid_0's auc: 0.800997
# [1400]	valid_0's auc: 0.801255
# [1500]	valid_0's auc: 0.803146
# name lgb2,fold:6
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 112000, number of negative: 15560
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293146
# [LightGBM] [Info] Number of data points in the train set: 127560, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (153.77 MB) transferred to GPU in 0.110880 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.878018 -> initscore=1.973795
# [LightGBM] [Info] Start training from score 1.973795
# [100]	valid_0's auc: 0.803266
# [200]	valid_0's auc: 0.825065
# [300]	valid_0's auc: 0.832717
# [400]	valid_0's auc: 0.837418
# [500]	valid_0's auc: 0.840506
# [600]	valid_0's auc: 0.841945
# [700]	valid_0's auc: 0.841241
# [800]	valid_0's auc: 0.840316
# [900]	valid_0's auc: 0.840654
# [1000]	valid_0's auc: 0.841162
# [1100]	valid_0's auc: 0.841339
# [1200]	valid_0's auc: 0.841955
# [1300]	valid_0's auc: 0.842333
# [1400]	valid_0's auc: 0.841576
# [1500]	valid_0's auc: 0.84206
# name lgb2,fold:7
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 114601, number of negative: 14171
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293343
# [LightGBM] [Info] Number of data points in the train set: 128772, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1261 dense feature groups (155.23 MB) transferred to GPU in 0.092962 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.889953 -> initscore=2.090259
# [LightGBM] [Info] Start training from score 2.090259
# [100]	valid_0's auc: 0.569734
# [200]	valid_0's auc: 0.635088
# [300]	valid_0's auc: 0.657075
# [400]	valid_0's auc: 0.662951
# [500]	valid_0's auc: 0.667187
# [600]	valid_0's auc: 0.674771
# [700]	valid_0's auc: 0.681193
# [800]	valid_0's auc: 0.690084
# [900]	valid_0's auc: 0.689688
# [1000]	valid_0's auc: 0.689436
# [1100]	valid_0's auc: 0.694507
# [1200]	valid_0's auc: 0.700796
# [1300]	valid_0's auc: 0.704877
# [1400]	valid_0's auc: 0.708604
# [1500]	valid_0's auc: 0.711183
# name lgb2,fold:8
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 117634, number of negative: 15434
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293490
# [LightGBM] [Info] Number of data points in the train set: 133068, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (159.90 MB) transferred to GPU in 0.110600 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.884014 -> initscore=2.031005
# [LightGBM] [Info] Start training from score 2.031005
# [100]	valid_0's auc: 0.77654
# [200]	valid_0's auc: 0.796825
# [300]	valid_0's auc: 0.800995
# [400]	valid_0's auc: 0.804637
# [500]	valid_0's auc: 0.806256
# [600]	valid_0's auc: 0.808332
# [700]	valid_0's auc: 0.809357
# [800]	valid_0's auc: 0.810411
# [900]	valid_0's auc: 0.811018
# [1000]	valid_0's auc: 0.8106
# [1100]	valid_0's auc: 0.811322
# [1200]	valid_0's auc: 0.8119
# [1300]	valid_0's auc: 0.811766
# [1400]	valid_0's auc: 0.812076
# [1500]	valid_0's auc: 0.812347
# name lgb2,fold:9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 114884, number of negative: 15568
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 293512
# [LightGBM] [Info] Number of data points in the train set: 130452, number of used features: 1283
# [LightGBM] [Info] Using GPU Device: Tesla P100-PCIE-16GB, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 16
# [LightGBM] [Info] 1260 dense feature groups (156.75 MB) transferred to GPU in 0.111903 secs. 1 sparse feature groups
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.880661 -> initscore=1.998705
# [LightGBM] [Info] Start training from score 1.998705
# [100]	valid_0's auc: 0.7422
# [200]	valid_0's auc: 0.760876
# [300]	valid_0's auc: 0.770088
# [400]	valid_0's auc: 0.772987
# [500]	valid_0's auc: 0.777843
# [600]	valid_0's auc: 0.778703
# [700]	valid_0's auc: 0.778074
# [800]	valid_0's auc: 0.779228
# [900]	valid_0's auc: 0.780649
# [1000]	valid_0's auc: 0.782182
# [1100]	valid_0's auc: 0.78206
# [1200]	valid_0's auc: 0.781734
# [1300]	valid_0's auc: 0.781511
# [1400]	valid_0's auc: 0.782384
# [1500]	valid_0's auc: 0.783975
# cnt:118
# weight_roc_auc:0.7129295529700965
# [0.9962134  0.99461034 0.99230637 0.85411459 0.99726238 0.51028478
#  0.98684371 0.9400683  0.99685704 0.99344051]

# %% [markdown]
# #### 保存为json的提交文件。

# %%
path='/kaggle/input/'
with open(path+"2024kddcupwhoiswho/2024kddcupwhoiswho/ind_test_author_submit.json") as f:
    submission=json.load(f)
cnt=0
for id,names in submission.items():
    for name in names:
        submission[id][name]=test_preds[cnt]
        cnt+=1
with open('2024kddmodel.json', 'w', encoding='utf-8') as f:
    json.dump(submission, f, ensure_ascii=False, indent=4)

# %% [markdown]
# #### 这里是用optuna找参数的代码.

# %%
# #这里是找参数的.
# import optuna#自动超参数优化软件框架
# choose_cols=[ col for col in valid_feats.drop(['authorid'],axis=1).columns]
# print(f"choose_cols:{choose_cols}")


# def weight_rocauc(authorid,y_true,y_pro):
#     max_authorid=np.max(authorid).astype(int)+1
#     total_weight_auc=0
#     for id in range(max_authorid):
#         cur_idx=np.where(authorid==id)[0]
#         auc=roc_auc_score(y_true[cur_idx],y_pro[cur_idx])
#         weight_auc=np.sum(y_true[cur_idx]==0)*auc
#         total_weight_auc+=weight_auc
#     total_weight_auc/=np.sum(y_true==0)
#     return total_weight_auc


# def objective(trial):
#     param = {
#         "boosting_type": "gbdt",
#         "objective": "binary",
#         "metric": "auc",
#         'random_state': trial.suggest_int('random_state',2024,2024),
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 2000),
#         'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
#         'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),#对数分布的建议值
#         'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.8),#浮点数
#         'subsample': trial.suggest_float('subsample', 0.3, 0.8),
#         'learning_rate': trial.suggest_float('learning_rate', 1e-4, 0.5, log=True),
#         'num_leaves' : trial.suggest_int('num_leaves', 8, 64),#整数
#         'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
#         'max_bin':225,
#         'device':'gpu','gpu_use_dp':True,#GPU环境的参数
#     }
#     model = LGBMClassifier(**param)  
    
#     X=train_feats[choose_cols].copy()
#     y=train_feats[Config.TARGET_NAME].copy()
#     oof_pred_pro=np.zeros((len(X),2))
    
#     #10折交叉验证
#     gkf = GroupKFold(n_splits=Config.num_folds)

#     for fold, (train_index, valid_index) in (enumerate(gkf.split(X,y,train_feats['authorid'].values))):
#         print(f"fold:{fold}")

#         X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
#         y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
     
#         model.fit(X_train,y_train,eval_set=[(X_valid, y_valid)],
#                       callbacks=[log_evaluation(500)]#,early_stopping(100)
#                      )
        
#         oof_pred_pro[valid_index]=model.predict_proba(X_valid)
        
#     weight_roc_auc=weight_rocauc(train_feats['authorid'].values,y.values,oof_pred_pro[:,1])
    
    
#     return weight_roc_auc
# lgb_params = {"boosting_type": "gbdt","objective": "binary","metric": "auc",       
#      'random_state': 2024, 'n_estimators': 1536,
#      'reg_alpha': 2.6756579164398144, 'reg_lambda': 1.6187614490530422, 
#      'colsample_bytree': 0.6631684151930536, 'subsample': 0.6162557596563916, 
#      'learning_rate': 0.030479973315991688, 'num_leaves': 50, 'min_child_samples': 62,
#      'max_bin':225,
#      'device':'gpu','gpu_use_dp':True,#GPU环境的参数
# }
# #创建的研究命名,找最小值.
# study = optuna.create_study(direction='maximize', study_name='Optimize boosting hyperparameters')
# #目标函数,尝试的次数
# study.optimize(objective, n_trials=20)
# lgbm_params=study.best_trial.params

# #输出最佳的参数
# print('lgbm_params=', lgbm_params)
